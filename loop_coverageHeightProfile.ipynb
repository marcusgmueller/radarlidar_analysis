# %%
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import numpy as np
from RadarLidarWindSpeed import RadarLidarWindSpeed
from matplotlib.colors import ListedColormap
from dateutil.relativedelta import *

# %%
start = datetime(2019, 4, 1)
for i in range(23):
    dateBegin=start+relativedelta(months=+i)
    print(dateBegin)
    dateEnd=start+relativedelta(months=+i+1)
    #plot
    analysis = RadarLidarWindSpeed(dateBegin, dateEnd)
    analysis.importDataset()
    result = analysis.getHeightProfile()
    heightGrid = analysis.heightGrid
    plt.figure(figsize=(20,10))
    plt.plot(result['radar Coverage'].tolist(),heightGrid, 'go-', label='Radar')
    plt.plot(result['lidar Coverage'].tolist(),heightGrid, 'rs-', label='Lidar')
    plt.plot(result['total Coverage'].tolist(),heightGrid, 'b*-', label='Total')
    axes = plt.axes()
    axes.set_ylim([0, 12000])
    axes.set_xlim([0, 100])
    plt.xlabel("coverage [%]")
    plt.ylabel("height [m]")
    plt.legend()
    plt.title('data coverage by height: '+dateBegin.strftime("%Y-%m-%d")+" to "+dateEnd.strftime("%Y-%m-%d"))
    plt.savefig("/work/radarlidarwind/coverageHeightPlot_"+str(dateBegin)+"_"+str(dateEnd)+".png",dpi=300)
    plt.show()
# Out:
# 2019-04-01 00:00:00
# <ipython-input-2-cb896ab860d7>:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   axes = plt.axes()
# 2019-05-01 00:00:00
# <ipython-input-2-cb896ab860d7>:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   axes = plt.axes()
# 2019-06-01 00:00:00
# <ipython-input-2-cb896ab860d7>:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   axes = plt.axes()
# 2019-07-01 00:00:00
# <ipython-input-2-cb896ab860d7>:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   axes = plt.axes()
# 2019-08-01 00:00:00
